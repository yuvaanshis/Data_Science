# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df=pd.read_csv("./forestfires.csv")  # dataframe
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# # I want to know how many columns and rows are there in the dataset

# %%
df.shape
# Out:
# (517, 13)

# %% [markdown]
# # Types of Datatypes present in Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   FFMC    517 non-null    float64
#  5   DMC     517 non-null    float64
#  6   DC      517 non-null    float64
#  7   ISI     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   RH      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %% [markdown]
# # Measures of Central tendency:
#
#             Mean
#             Median
#             Mode

# %%
df.mean()
# Out:
# X         4.669246
# Y         4.299807
# FFMC     90.644681
# DMC     110.872340
# DC      547.940039
# ISI       9.021663
# temp     18.889168
# RH       44.288201
# wind      4.017602
# rain      0.021663
# area     12.847292
# dtype: float64

# %%
df.median()
# Out:
# X         4.00
# Y         4.00
# FFMC     91.60
# DMC     108.30
# DC      664.20
# ISI       8.40
# temp     19.30
# RH       42.00
# wind      4.00
# rain      0.00
# area      0.52
# dtype: float64

# %%
df.mode()
# Out:
#      X    Y month  day  FFMC   DMC     DC  ISI  temp    RH  wind  rain  area
# 0  4.0  4.0   aug  sun  91.6  99.0  745.3  9.6  17.4  27.0   2.2   0.0   0.0
# 1  NaN  NaN   NaN  NaN  92.1   NaN    NaN  NaN  19.6   NaN   3.1   NaN   NaN

# %%
from statistics import mean 
from scipy import stats

# %% [markdown]
# #    Measures of Dispersion:
# Determined by the standard deviation, and the variance. They help us identify how dispersed our data is. First of all, the standard deviation gives us how our data is far away from the mean value. Then the variance is the squared value of the standard deviation.

# %%
df.std()
# Out:
# X         2.313778
# Y         1.229900
# FFMC      5.520111
# DMC      64.046482
# DC      248.066192
# ISI       4.559477
# temp      5.806625
# RH       16.317469
# wind      1.791653
# rain      0.295959
# area     63.655818
# dtype: float64

# %%
df.var()
# Out:
# X           5.353568
# Y           1.512655
# FFMC       30.471624
# DMC      4101.951889
# DC      61536.835467
# ISI        20.788832
# temp       33.716898
# RH        266.259802
# wind        3.210019
# rain        0.087592
# area     4052.063225
# dtype: float64

# %%
# Range =max-min
x=df.max()
y=df.min()

#range = max-min 
# Note object/string type data we cannot find the range

# in this case you have to drop the string columns

# %%
# Delete multiple columns from the dataframe
df = df.drop(["month", "day"], axis=1)

# %%
#Skewness and Kurtosis

# %%
df.skew()
# Out:
# X        0.036246
# Y        0.417296
# FFMC    -6.575606
# DMC      0.547498
# DC      -1.100445
# ISI      2.536325
# temp    -0.331172
# RH       0.862904
# wind     0.571001
# rain    19.816344
# area    12.846934
# dtype: float64

# %%
df.kurtosis()
# Out:
# X        -1.172331
# Y         1.420553
# FFMC     67.066041
# DMC       0.204822
# DC       -0.245244
# ISI      21.458037
# temp      0.136166
# RH        0.438183
# wind      0.054324
# rain    421.295964
# area    194.140721
# dtype: float64

# %%
df
# Out:
#      X  Y  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 11 columns]

# %%
import seaborn as sns

sns.set_style('darkgrid')
sns.distplot(df)

# %%
sns.boxplot(df)

# %%
# calucalting z value
import numpy as np
from scipy import stats

# %%
z = np.abs(stats.zscore(df))
print(z)
# Out:
# [[1.00831277 0.56986043 0.80595947 ... 1.49861442 0.07326831 0.20201979]
#  [1.00831277 0.24400101 0.00810203 ... 1.74175564 0.07326831 0.20201979]
#  [1.00831277 0.24400101 0.00810203 ... 1.51828184 0.07326831 0.20201979]
#  ...
#  [1.00831277 0.24400101 1.64008316 ... 1.49861442 0.07326831 0.02653216]
#  [1.58736044 0.24400101 0.68095666 ... 0.00983371 0.07326831 0.20201979]
#  [0.57570057 1.05786246 2.02087875 ... 0.26950853 0.07326831 0.20201979]]

# %% [markdown]
# # A pairs plot allows us to see both distribution of single variables and relationships between two variables . Pair plots are a great method to identify trends for follow-up analysis and, fortunately, are easily implemented in Python

# %%
sns.pairplot(df)
df
# Out:
#      X  Y  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 11 columns]
